# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
import numpy as np

# %%
plt.xkcd()

x = np.linspace(-np.pi,np.pi,100)
y = np.cos(x)

plt.plot(x,y)
